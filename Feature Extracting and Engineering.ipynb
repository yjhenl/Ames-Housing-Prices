# %% [markdown]
# ## 01 Import Libraries

# %%
import pandas as pd # Data Processing
import numpy as np # Linear Algebra
import os # Import and Save files
# Data Visualization
import matplotlib
import matplotlib.pyplot as plt # Matlab-style plotting
import seaborn as sns
# Statistical Computation
from scipy import stats
from scipy.stats import norm, skew

# %% [markdown]
# ## 02 Import Dataset

# %%
# Assign folder path to a string
path = r'D:\Data Analyst\Task 6.1'

# %%
# Import dataset
df_train = pd.read_csv(os.path.join(path,'Housing Price','train.csv'), index_col = False) 
df_test = pd.read_csv(os.path.join(path,'Housing Price','test.csv'), index_col = False)

# %%
# Check total column and row number of training dataset
df_train.shape
# Out:
# (1460, 81)

# %%
# Check total column and row number of test dataset
df_test.shape
# Out:
# (1459, 80)

# %%
# Check the first five rows of the training dataset
pd.set_option('display.max_columns', None)
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_train['YearBuilt'].value_counts()
# Out:
# 2006    67
# 2005    64
# 2004    54
# 2007    49
# 2003    45
# 1976    33
# 1977    32
# 1920    30
# 1959    26
# 1998    25
# 1999    25
# 1965    24
# 2000    24
# 1970    24
# 1954    24
# 1958    24
# 2008    23
# 2002    23
# 1972    23
# 1971    22
# 1968    22
# 1950    20
# 1957    20
# 2001    20
# 1994    19
# 1962    19
# 1940    18
# 1966    18
# 2009    18
# 1995    18
# 1910    17
# 1993    17
# 1960    17
# 1963    16
# 1978    16
# 1925    16
# 1955    16
# 1967    16
# 1996    15
# 1941    15
# 1964    15
# 1961    14
# 1948    14
# 1956    14
# 1969    14
# 1997    14
# 1992    13
# 1953    12
# 1990    12
# 1949    12
# 1973    11
# 1988    11
# 1900    10
# 1974    10
# 1915    10
# 1980    10
# 1984     9
# 1926     9
# 1936     9
# 1979     9
# 1930     9
# 1922     8
# 1975     8
# 1939     8
# 1916     8
# 1928     7
# 1914     7
# 1923     7
# 1924     7
# 1918     7
# 1946     7
# 1935     6
# 1951     6
# 1921     6
# 1945     6
# 1982     6
# ...

# %%
# Check the first five rows of the test dataset
pd.set_option('display.max_columns', None)
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# Check datatype of training dataset
pd.set_option('display.max_rows', None)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Check datatype of test dataset
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %% [markdown]
# ###### Summary:
#
# * There are too many (80) attributes in the training dataset for our prediction. We need to reduce the number of attribute.
#
# * We can seperate the data to numerical data and categorical data later after data wrangling.
#
# * Id is not important when we investiagte the relationships among data, so we can drop it first.
#
# * By checking the data in Excel, incosistent information of non-null values are found. Some NAs in the dataset have meaning,  which cannot be represented through the argument info() here. Therefore, we cannot directly remove these NAs and they need to invetsigate further manually.
#
# * Seperate datasets (training data and test data) might increase the complicity of data cleaning, so I would merge them together for the convenience of data wrangling and consistency check.

# %% [markdown]
# ## 03 Data Wrangling

# %% [markdown]
# Id column is not relevant to the correlation matrix, but I need thhis column for merging numerical and categorical data later, so I would keep it first.

# %%
df = pd.concat([df_train, df_test], axis = 0)

# %%
df.shape
# Out:
# (2919, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %% [markdown]
# ### Change Datatype

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# Some columns are categorical data but marked as categorical data

df = df.astype({'MSSubClass': 'object', 'OverallQual': 'object', 'OverallCond': 'object'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   object
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
# Alley            2721
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         24
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           81
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinSF1          1
# BsmtFinType2       80
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
# Some NAs don't mean missing value, for which we need to rename the category to prevent misunderstanding
df['Alley'] = df['Alley'].fillna("NO")
df['MasVnrType'] = df['MasVnrType'].fillna("NO")
df['BsmtQual'] = df['BsmtQual'].fillna("NO")
df['BsmtCond'] = df['BsmtCond'].fillna("NO")
df['BsmtExposure'] = df['BsmtExposure'].fillna("NO")
df['BsmtFinType1'] = df['BsmtFinType1'].fillna("NO")
df['BsmtFinType2'] = df['BsmtFinType2'].fillna("NO")
df['FireplaceQu'] = df['FireplaceQu'].fillna("NO")
df['GarageType'] = df['GarageType'].fillna("NO")
df['GarageFinish'] = df['GarageFinish'].fillna("NO")
df['GarageQual'] = df['GarageQual'].fillna("NO")
df['GarageCond'] = df['GarageCond'].fillna("NO")
df['PoolQC'] = df['PoolQC'].fillna("NO")
df['Fence'] = df['Fence'].fillna("NO")
df['MiscFeature'] = df['MiscFeature'].fillna("NO")

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
# Alley               0
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType          0
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtCond            0
# BsmtExposure        0
# BsmtFinType1        0
# BsmtFinSF1          1
# BsmtFinType2        0
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
# If missing value make up over 5 % of total rows, the distribution might be biased when we impute values to NaNs.
# Therefore, these columns would be removed

2919*0.05
# Out:
# 145.95000000000002

# %%
df_1 = df.drop(columns = ['LotFrontage','GarageYrBlt'])

# %%
# There are still NaNs in columns. We would leave it to the end of data wrangling to clean them.
# If we clean them know but they would be removed in the end of the data wrangling step, we would waste our time thinking value imputation now. 

df_1.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotArea             0
# Street              0
# Alley               0
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType          0
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtCond            0
# BsmtExposure        0
# BsmtFinType1        0
# BsmtFinSF1          1
# BsmtFinType2        0
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %% [markdown]
# ### Univariable study

# %%
# Histogram

sns.displot(df_1['SalePrice'])

# %% [markdown]
# ###### Summary:
#
# * The most important feature 'Saleprice' is right skewed and has a long tail. We might need to use log transformation to make it more like normal distribution.

# %% [markdown]
# ### Multivariate study

# %% [markdown]
# #### Feature Extracting of Numerical Data

# %%
# Select only numerical data for feature extracting
df_num = df_1.select_dtypes(exclude = ['object']).copy()

# %%
df_num.shape
# Out:
# (2919, 33)

# %%
df_num.head()
# Out:
#    Id  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0   1     8450       2003          2003       196.0       706.0         0.0
# 1   2     9600       1976          1976         0.0       978.0         0.0
# 2   3    11250       2001          2002       162.0       486.0         0.0
# 3   4     9550       1915          1970         0.0       216.0         0.0
# 4   5    14260       2000          2000       350.0       655.0         0.0
#
#    BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0      150.0        856.0       856       854             0       1710
# 1      284.0       1262.0      1262         0             0       1262
# 2      434.0        920.0       920       866             0       1786
# 3      540.0        756.0       961       756             0       1717
# 4      490.0       1145.0      1145      1053             0       2198
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# ...

# %%
# Take a look at the triangle correlation heat map

plt.figure(figsize = (35, 30))
sns.set_style("whitegrid", {'axes.grid' : False})
# Define the mask to cover the values in the upper triangle 
mask = np.triu(np.ones_like(df_num.corr()))
heatmap = sns.heatmap(df_num.corr(), mask = mask, vmin=-1, vmax=1, annot=True, fmt = '.2f', cmap='BrBG', annot_kws={"size": 15, "color": "black"}, linewidths=0.1) 
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':30}, pad =16)
# Out:
# Text(0.5, 1.0, 'Triangle Correlation Heatmap')

# %%
# Most correlated features

plt.figure(figsize = (15, 10))
sns.set_style("whitegrid", {'axes.grid' : False})

num_corr = df_num.corr()
top_num_corr = num_corr.index[abs(num_corr['SalePrice']) > 0.5]

mask = np.triu(np.ones_like(df_num[top_num_corr].corr()))
heatmap = sns.heatmap(df_num[top_num_corr].corr(), mask = mask, vmin=-1, vmax=1, annot=True, fmt = '.2f', cmap='BrBG', annot_kws={"size": 12, "color": "black"}, linewidths=0.5) 
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':20}, pad =16)

plt.savefig('correlation_heatmap.png')

# %%
num_corr = df_num.corr()

num_corr.to_csv(os.path.join(path,'num_corr.csv'))

# %%
# Select only Saleprice in the correlation map and compare the value with other features

df_num_matrix = df_num[top_num_corr].corr()
feature_corr = df_num_matrix['SalePrice'].drop(['SalePrice'])
feature_corr.sort_values(ascending = False)
# Out:
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %% [markdown]
# ###### Summary:
#
# The number of absolute value represents the following relationship:
#
# * 0.1–0.3: very weak relationship
# * 0.3–0.5: weak relationship
# * 0.5–1.0: moderate relationship
# * 0.7–1.0: strong relationship
#
# I have removed features having weak relationship with SalePrice, since these features are not very important and won't got to the prediction model in the end.
#
# Moreover, we can find out that some features have strong correlation with wach other such as:
#
# * 'TotalBsmtSF' and '1stFlrSF'
# * 'GrLivArea' and 'TotRmsAbvGrd'
# * 'GarageCars' and 'GarageArea'
#
# On of the faetures above should be removed, becuase each parir contribute the same to the model and we already have too many features here.

# %%
df_num[top_num_corr].head()
# Out:
#    YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  FullBath  \
# 0       2003          2003        856.0       856       1710         2
# 1       1976          1976       1262.0      1262       1262         2
# 2       2001          2002        920.0       920       1786         2
# 3       1915          1970        756.0       961       1717         1
# 4       2000          2000       1145.0      1145       2198         2
#
#    TotRmsAbvGrd  GarageCars  GarageArea  SalePrice
# 0             8         2.0       548.0   208500.0
# 1             6         2.0       460.0   181500.0
# 2             6         2.0       608.0   223500.0
# 3             7         3.0       642.0   140000.0
# 4             9         3.0       836.0   250000.0

# %%
# Create a subset for features with moderate to strong relationship 
top_num_f = df_num[['Id','SalePrice', 'GrLivArea', 'GarageCars', 'TotalBsmtSF','FullBath', 'YearBuilt', 'YearRemodAdd']]

# %%
top_num_f.head()
# Out:
#    Id  SalePrice  GrLivArea  GarageCars  TotalBsmtSF  FullBath  YearBuilt  \
# 0   1   208500.0       1710         2.0        856.0         2       2003
# 1   2   181500.0       1262         2.0       1262.0         2       1976
# 2   3   223500.0       1786         2.0        920.0         2       2001
# 3   4   140000.0       1717         3.0        756.0         1       1915
# 4   5   250000.0       2198         3.0       1145.0         2       2000
#
#    YearRemodAdd
# 0          2003
# 1          1976
# 2          2002
# 3          1970
# 4          2000

# %%
top_num_f.shape
# Out:
# (2919, 8)

# %%
# Warning days that duplicates are found, so I craeted a subset to remove dupicates
top_num_f_2 = top_num_f[~top_num_f.index.duplicated()]

# %%
# Check the distribution of thsese numerical features: Pair plots

sns.set_style(style = 'white')
g = sns.pairplot(top_num_f_2)

# %% [markdown]
# ###### Summary:
#
# * SalePrice, GrLivArea, TotalBsmtSF are right skewed distribtuion.
#
# * YearBuilt, YearRemodAdd are left skewed. Meaning: Most of the buildings in the dataset are relatively new.
#
# * It doesn't make sense that the SalePrice decreases when accomodating GarageCars increases to 4, so the outliers must be dropped.
#
# * Outliers can be observed. We would take a closer look at the scatterplots later.
#
# * Scatterplot of GrLivArea and TotalBsmtSF is interesting. There is a line in it and all points are above the line. It makes sense that the basement area is usually equal or smaller than the living area above ground.
#
# * Scatterplot of YearBuilt and YearRemodAdd is also interesting. There is a line in it and all points are above the line. It means taht some buildings are renovated while some are not.
#
# * Duplicates should be removed later after we merge numerical and categorical data. Otherwise, we might delete some duplicates in numercial data, which are not duplicates in the whole data.

# %%
# Scatterplot: GrLivArea vs SalePrice

top_num_f.plot.scatter(x = 'GrLivArea', y= 'SalePrice', color='green')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %% [markdown]
# GrLivArea and SalePrice have a positive relationship. However, it is a special case that the buildings with higher GrLivArea cost less. We should remove the two spots with the highest GrLivArea, otherwise the regression would be biased.

# %%
# Remove outliers

top_num_f = top_num_f.drop(top_num_f[top_num_f['GrLivArea'] > 4500].index)

# %%
# Check result
top_num_f.plot.scatter(x = 'GrLivArea', y= 'SalePrice', color='green')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
# Scatterplot: GarageCars vs SalePrice

top_num_f.plot.scatter(x = 'GarageCars', y= 'SalePrice', color='green')
# Out:
# <AxesSubplot:xlabel='GarageCars', ylabel='SalePrice'>

# %% [markdown]
# It doesn't make sense that house with more accomodation for cars costs less. They might located far away from other buildings on the countryside. Therefore, the data with 4 GarageCars should also be removed.

# %%
# Remove outliers

top_num_f = top_num_f.drop(top_num_f[top_num_f['GarageCars'] > 3].index)

# %%
top_num_f.plot.scatter(x = 'GarageCars', y= 'SalePrice', color='green')
# Out:
# <AxesSubplot:xlabel='GarageCars', ylabel='SalePrice'>

# %%
# Scatterplot: TotalBsmtSF vs SalePrice

top_num_f.plot.scatter(x = 'TotalBsmtSF', y= 'SalePrice', color='green')
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %% [markdown]
# We can see that there are some houses without basement. Their varied sale privce might result from different house location. We can also observe that the data points with TotalBsmtSF at around 3100 are a liitle far away from the other. They can be removed.

# %%
top_num_f = top_num_f.drop(top_num_f[top_num_f['TotalBsmtSF'] > 3000].index)

# %%
top_num_f.plot.scatter(x = 'TotalBsmtSF', y= 'SalePrice', color='green')
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
# Scatterplot: FullBath vs SalePrice

top_num_f.plot.scatter(x = 'FullBath', y= 'SalePrice', color='green')
# Out:
# <AxesSubplot:xlabel='FullBath', ylabel='SalePrice'>

# %% [markdown]
# No outlier is found. Most of the house are equipped with 1 or 2 fullbath.

# %%
# Scatterplot: YearBuilt vs SalePrice

top_num_f.plot.scatter(x = 'YearBuilt', y= 'SalePrice', color='green')
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %% [markdown]
# No outlier is found. The house prices increase over years.

# %%
# Scatterplot: YearRemodAdd vs SalePrice

top_num_f.plot.scatter(x = 'YearRemodAdd', y= 'SalePrice', color='green')
# Out:
# <AxesSubplot:xlabel='YearRemodAdd', ylabel='SalePrice'>

# %% [markdown]
# No outlier is found. More house are renovated in recent years.

# %%
top_num_f.shape
# Out:
# (2873, 8)

# %%
top_num_f.to_csv(os.path.join(path,'num for PPT.csv'))

# %% [markdown]
# ##### Improve Normality

# %%
top_num_f['SalePrice'].isnull().sum()
# Out:
# 1436

# %%
# Check histogram of numerical output (SalePrice)

sns.displot(top_num_f['SalePrice'], kde =True)

# %%
# Apply log transformation

Log_Price = top_num_f[['SalePrice']].applymap(lambda x: np.log(x+1))

# %%
# Check histogram of numerical output (SalePrice)

sns.displot(Log_Price, kde =True)

# %%
# Check histogram of numerical output (GrLivArea)

sns.displot(top_num_f['GrLivArea'], kde =True)

# %%
# Check histogram of numerical output (TotalBsmtSF)

sns.displot(top_num_f['TotalBsmtSF'], kde =True)

# %%
top_num_f.head()
# Out:
#    Id  SalePrice  GrLivArea  GarageCars  TotalBsmtSF  FullBath  YearBuilt  \
# 0   1   208500.0       1710         2.0        856.0         2       2003
# 1   2   181500.0       1262         2.0       1262.0         2       1976
# 2   3   223500.0       1786         2.0        920.0         2       2001
# 3   4   140000.0       1717         3.0        756.0         1       1915
# 4   5   250000.0       2198         3.0       1145.0         2       2000
#
#    YearRemodAdd
# 0          2003
# 1          1976
# 2          2002
# 3          1970
# 4          2000

# %%
# Insert columns after log(x+1) transformation to our dataframe
pd.options.mode.chained_assignment = None
top_num_f.loc[:,'Log_Price'] = Log_Price

# %%
top_num_f.head()
# Out:
#    Id  SalePrice  GrLivArea  GarageCars  TotalBsmtSF  FullBath  YearBuilt  \
# 0   1   208500.0       1710         2.0        856.0         2       2003
# 1   2   181500.0       1262         2.0       1262.0         2       1976
# 2   3   223500.0       1786         2.0        920.0         2       2001
# 3   4   140000.0       1717         3.0        756.0         1       1915
# 4   5   250000.0       2198         3.0       1145.0         2       2000
#
#    YearRemodAdd  Log_Price
# 0          2003  12.247699
# 1          1976  12.109016
# 2          2002  12.317171
# 3          1970  11.849405
# 4          2000  12.429220

# %%
top_num_f.to_csv(os.path.join(path, 'SalePrice for regression.csv'))

# %%
# Drop unnecessary columns
top_num_f1 = top_num_f.drop(['SalePrice'],axis = 1)

# %%
top_num_f1.head()
# Out:
#    Id  GrLivArea  GarageCars  TotalBsmtSF  FullBath  YearBuilt  YearRemodAdd  \
# 0   1       1710         2.0        856.0         2       2003          2003
# 1   2       1262         2.0       1262.0         2       1976          1976
# 2   3       1786         2.0        920.0         2       2001          2002
# 3   4       1717         3.0        756.0         1       1915          1970
# 4   5       2198         3.0       1145.0         2       2000          2000
#
#    Log_Price
# 0  12.247699
# 1  12.109016
# 2  12.317171
# 3  11.849405
# 4  12.429220

# %% [markdown]
# #### Feature Extracting of Categorical Data

# %%
# Select cateforical data and Sale Price for feature extracting

df_cat= df.select_dtypes(include = ['object'])

# %%
df_cat.shape
# Out:
# (2919, 46)

# %%
df_cat.loc[:,'SalePrice']= df['SalePrice']

# %%
df_cat.head()
# Out:
#   MSSubClass MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# 0         60       RL   Pave    NO      Reg         Lvl    AllPub    Inside
# 1         20       RL   Pave    NO      Reg         Lvl    AllPub       FR2
# 2         60       RL   Pave    NO      IR1         Lvl    AllPub    Inside
# 3         70       RL   Pave    NO      IR1         Lvl    AllPub    Corner
# 4         60       RL   Pave    NO      IR1         Lvl    AllPub       FR2
#
#   LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#   OverallQual OverallCond RoofStyle RoofMatl Exterior1st Exterior2nd  \
# ...

# %%
df_cat.info()
df_cat.to_csv(os.path.join(path, 'cat for PPT.csv'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 47 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   object
#  1   MSZoning       2915 non-null   object
#  2   Street         2919 non-null   object
#  3   Alley          2919 non-null   object
#  4   LotShape       2919 non-null   object
#  5   LandContour    2919 non-null   object
#  6   Utilities      2917 non-null   object
#  7   LotConfig      2919 non-null   object
#  8   LandSlope      2919 non-null   object
#  9   Neighborhood   2919 non-null   object
#  10  Condition1     2919 non-null   object
#  11  Condition2     2919 non-null   object
#  12  BldgType       2919 non-null   object
#  13  HouseStyle     2919 non-null   object
#  14  OverallQual    2919 non-null   object
#  15  OverallCond    2919 non-null   object
#  16  RoofStyle      2919 non-null   object
# ...

# %% [markdown]
# ###### Summary:
#
# * Several columns have too many missing values. Imputing values to them might result to distribution bias, so they should be removed.
#
# * We have too many (47) categorical features for prediction, so the number of categorical features needs to be reduced.

# %%
# Take a look at each feature counts

import warnings
warnings.simplefilter("ignore", UserWarning)

fig,ax = plt.subplots(22, 2, figsize=(20,40))
cat_cols = df_cat.columns.to_list()[:-1]
 
for i,ax in enumerate(fig.axes):
    if i < len(cat_cols): 
        ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=90)
        sns.countplot(data = df_cat, x = cat_cols[i], ax = ax)
        
sns.set_style("whitegrid", {'axes.grid' : False})      
fig.tight_layout()

# %%
# Remove features with less contribution

df_cat_1 =  df_cat.drop(columns = ['Street', 'LandContour', 'Utilities', 'LandSlope', 'Condition1', 'Condition2', 'RoofMatl', 'BsmtCond', 'BsmtFinType2', 'Heating','CentralAir', 'Electrical', 'Functional', 'GarageQual', 'GarageCond'], axis=1)

# %%
df_cat_1.shape
# Out:
# (2919, 32)

# %%
# Take a look at each feature counts again check if we remove features with only one dominant variable 

fig,ax2 = plt.subplots(14, 2, figsize=(20,40))
cat_cols = df_cat_1.columns.to_list()[:-1]
 
for i,ax in enumerate(fig.axes):
    if i < len(cat_cols): 
        ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=90)
        sns.countplot(data = df_cat_1, x = cat_cols[i], ax = ax)
        
import warnings
warnings.simplefilter("ignore", UserWarning)

sns.set_style("whitegrid", {'axes.grid' : False})      
fig.tight_layout()

# %%
df_cat_1.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'Alley', 'LotShape', 'LotConfig',
#        'Neighborhood', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'RoofStyle', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1',
#        'HeatingQC', 'KitchenQual', 'FireplaceQu', 'GarageType', 'GarageFinish',
#        'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df_cat_1['MiscFeature'].value_counts(normalize=True)
# Out:
# NO      0.964029
# Shed    0.032545
# Gar2    0.001713
# Othr    0.001370
# TenC    0.000343
# Name: MiscFeature, dtype: float64

# %%
#  The feature above contain significantly dominant variable, which would contribute less to the prediction model. 
# Therefore, we drop these column

df_cat_2 =  df_cat_1.drop(columns = ['MiscFeature'], axis=1)

# %%
# Take a look at the variation of each feature with sale price to check the similarity of contribution
# If the contribution of two features is similar, one of them can be removed

fig, ax3 = plt.subplots(14,2, figsize=(25,50))
cat_cols = df_cat_2 .columns.to_list()[:-1]

for i, ax in enumerate(fig.axes):
    if i < len(cat_cols):
        ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=0)
        sns.boxplot(data = df_cat_2 , x = cat_cols[i], y = df_cat['SalePrice'], ax = ax) 

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
df_cat_2 .columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'Alley', 'LotShape', 'LotConfig',
#        'Neighborhood', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'RoofStyle', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1',
#        'HeatingQC', 'KitchenQual', 'FireplaceQu', 'GarageType', 'GarageFinish',
#        'PavedDrive', 'PoolQC', 'Fence', 'SaleType', 'SaleCondition',
#        'SalePrice'],
#       dtype='object')

# %% [markdown]
# Some features have simliar distribution of SalePrice:
#
# * LotConfig and BldgType
# * LotShape and Fence
# * GarageFinish and PavedDrive
# * MasVnrType and ExterQual
# * Exterior1st and Exterior2nd
#
# They are highly correlated with each other, so we can remove one feature from each pair.

# %%
df_cat_3 = df_cat_2.drop(columns = ['LotConfig', 'GarageFinish', 'Fence','MasVnrType', 'Exterior1st'], axis = 1)

# %%
df_cat_3.shape
# Out:
# (2919, 26)

# %%
df_cat_3.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'Alley', 'LotShape', 'Neighborhood',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'RoofStyle',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtExposure', 'BsmtFinType1', 'HeatingQC', 'KitchenQual',
#        'FireplaceQu', 'GarageType', 'PavedDrive', 'PoolQC', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
# When we take a look at the variation above, we notice that some features have many missing value.
# Chekc the number of missing value

df_cat_3.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            4
# Alley               0
# LotShape            0
# Neighborhood        0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# RoofStyle           0
# Exterior2nd         1
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtExposure        0
# BsmtFinType1        0
# HeatingQC           0
# KitchenQual         1
# FireplaceQu         0
# GarageType          0
# PavedDrive          0
# PoolQC              0
# SaleType            1
# SaleCondition       0
# SalePrice        1459
# dtype: int64

# %% [markdown]
# 81 missing values make up 5.55 % of total value. Imputating values might not change the value distribution. However, imputating values for features with more than 5.55 % of missing value would have large impact on the value distribution. Therefore, it is better to remove these features.

# %%
# Remove features with too many missing values
df_cat_3.drop(['Alley', 'FireplaceQu', 'PoolQC', 'GarageType'], axis = 1, inplace = True)

# %%
# Impute mode values for missing values in specific columns

for col in ['MSZoning', 'Exterior2nd', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'KitchenQual','SaleType']:
    df_cat_3[col].fillna(df_cat_3[col].mode()[0], inplace = True)

# %%
# We would predict the SalePrice in the future, so we can leave it to that!

df_cat_3.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotShape            0
# Neighborhood        0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# RoofStyle           0
# Exterior2nd         0
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtExposure        0
# BsmtFinType1        0
# HeatingQC           0
# KitchenQual         0
# PavedDrive          0
# SaleType            0
# SaleCondition       0
# SalePrice        1459
# dtype: int64

# %%
df_cat_3.to_csv(os.path.join(path,'data for geo analysis.csv'))

# %%
df_cat_4 = df_cat_3.drop(columns = ['SalePrice'])

# %%
df_cat_4.head()
# Out:
#   MSSubClass MSZoning LotShape Neighborhood BldgType HouseStyle OverallQual  \
# 0         60       RL      Reg      CollgCr     1Fam     2Story           7
# 1         20       RL      Reg      Veenker     1Fam     1Story           6
# 2         60       RL      IR1      CollgCr     1Fam     2Story           7
# 3         70       RL      IR1      Crawfor     1Fam     2Story           7
# 4         60       RL      IR1      NoRidge     1Fam     2Story           8
#
#   OverallCond RoofStyle Exterior2nd ExterQual ExterCond Foundation BsmtQual  \
# 0           5     Gable     VinylSd        Gd        TA      PConc       Gd
# 1           8     Gable     MetalSd        TA        TA     CBlock       Gd
# 2           5     Gable     VinylSd        Gd        TA      PConc       Gd
# 3           5     Gable     Wd Shng        TA        TA     BrkTil       TA
# 4           5     Gable     VinylSd        Gd        TA      PConc       Gd
#
# ...

# %% [markdown]
# ######  Transform categorical data

# %%
from sklearn.preprocessing import LabelEncoder

for c in df_cat_4:
    le = LabelEncoder()
    df_cat_4[c] = le.fit_transform(df_cat_4[c].values)

# %%
df_cat_4.head()
# Out:
#    MSSubClass  MSZoning  LotShape  Neighborhood  BldgType  HouseStyle  \
# 0           5         3         3             5         0           5
# 1           0         3         3            24         0           2
# 2           5         3         0             5         0           5
# 3           6         3         0             6         0           5
# 4           5         3         0            15         0           5
#
#    OverallQual  OverallCond  RoofStyle  Exterior2nd  ExterQual  ExterCond  \
# 0            6            4          1           13          2          4
# 1            5            7          1            8          3          4
# 2            6            4          1           13          2          4
# 3            6            4          1           15          3          4
# 4            7            4          1           13          2          4
#
#    Foundation  BsmtQual  BsmtExposure  BsmtFinType1  HeatingQC  KitchenQual  \
# ...

# %%
df_cat_4.dtypes
# Out:
# MSSubClass       int32
# MSZoning         int32
# LotShape         int32
# Neighborhood     int32
# BldgType         int32
# HouseStyle       int32
# OverallQual      int32
# OverallCond      int32
# RoofStyle        int32
# Exterior2nd      int32
# ExterQual        int32
# ExterCond        int32
# Foundation       int32
# BsmtQual         int32
# BsmtExposure     int32
# BsmtFinType1     int32
# HeatingQC        int32
# KitchenQual      int32
# PavedDrive       int32
# SaleType         int32
# SaleCondition    int32
# dtype: object

# %%
df_cat_4.shape
# Out:
# (2919, 21)

# %%
df_cat_4.loc[:,'Id']= df['Id']

# %%
df_cat_4.head()
# Out:
#    MSSubClass  MSZoning  LotShape  Neighborhood  BldgType  HouseStyle  \
# 0           5         3         3             5         0           5
# 1           0         3         3            24         0           2
# 2           5         3         0             5         0           5
# 3           6         3         0             6         0           5
# 4           5         3         0            15         0           5
#
#    OverallQual  OverallCond  RoofStyle  Exterior2nd  ExterQual  ExterCond  \
# 0            6            4          1           13          2          4
# 1            5            7          1            8          3          4
# 2            6            4          1           13          2          4
# 3            6            4          1           15          3          4
# 4            7            4          1           13          2          4
#
#    Foundation  BsmtQual  BsmtExposure  BsmtFinType1  HeatingQC  KitchenQual  \
# ...

# %%
top_num_f1.shape
# Out:
# (2873, 8)

# %% [markdown]
# #### Merge numerical and categorical data

# %%
df_new = pd.merge(top_num_f1, df_cat_4, how = 'inner', on=["Id"])

# %%
df_new.shape
# Out:
# (2873, 29)

# %% [markdown]
# ## 04 Consistency check

# %%
# Check missing value
df_new.isnull().sum()
# Out:
# Id                  0
# GrLivArea           0
# GarageCars          1
# TotalBsmtSF         1
# FullBath            0
# YearBuilt           0
# YearRemodAdd        0
# Log_Price        1436
# MSSubClass          0
# MSZoning            0
# LotShape            0
# Neighborhood        0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# RoofStyle           0
# Exterior2nd         0
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtExposure        0
# BsmtFinType1        0
# HeatingQC           0
# KitchenQual         0
# PavedDrive          0
# SaleType            0
# SaleCondition       0
# dtype: int64

# %%
# Impute median values for missing values
df_new['GarageCars'] = df_new['GarageCars'].fillna(df_new['GarageCars'].median())
df_new['TotalBsmtSF'] = df_new['TotalBsmtSF'].fillna(df_new['TotalBsmtSF'].median())

# %%
# No misssing value anymore ! (SalePrice is what we want to predict, so we can just leave it to that !)
df_new.isnull().sum()
# Out:
# Id                  0
# GrLivArea           0
# GarageCars          0
# TotalBsmtSF         0
# FullBath            0
# YearBuilt           0
# YearRemodAdd        0
# Log_Price        1436
# MSSubClass          0
# MSZoning            0
# LotShape            0
# Neighborhood        0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# RoofStyle           0
# Exterior2nd         0
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtExposure        0
# BsmtFinType1        0
# HeatingQC           0
# KitchenQual         0
# PavedDrive          0
# SaleType            0
# SaleCondition       0
# dtype: int64

# %%
# Check duplicates
dup_new = df_new[df_new.duplicated()]

# %%
dup_new.shape
# Out:
# (0, 29)

# %%
df_new.shape
# Out:
# (2873, 29)

# %%
# Code for checking mixed types

for col in df_new.columns.tolist():
    weird = (df_new[[col]].applymap(type) != df_new[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_new[weird]) > 0:
         print(col)
# No mixed data type is found !

# %%
df_new.shape
# Out:
# (2873, 29)

# %% [markdown]
# ## 05 Feature Engineering

# %%
# Check if we can use raw column and integrate them into new features for predictive model.
pd.set_option('display.max_columns', None)

df_new.head()
# Out:
#    Id  GrLivArea  GarageCars  TotalBsmtSF  FullBath  YearBuilt  YearRemodAdd  \
# 0   1       1710         2.0        856.0         2       2003          2003
# 1   2       1262         2.0       1262.0         2       1976          1976
# 2   3       1786         2.0        920.0         2       2001          2002
# 3   4       1717         3.0        756.0         1       1915          1970
# 4   5       2198         3.0       1145.0         2       2000          2000
#
#    Log_Price  MSSubClass  MSZoning  LotShape  Neighborhood  BldgType  \
# 0  12.247699           5         3         3             5         0
# 1  12.109016           0         3         3            24         0
# 2  12.317171           5         3         0             5         0
# 3  11.849405           6         3         0             6         0
# 4  12.429220           5         3         0            15         0
#
#    HouseStyle  OverallQual  OverallCond  RoofStyle  Exterior2nd  ExterQual  \
# ...

# %%
# Add new features

df_new['Age'] = df_new['YearBuilt'].max() - df_new['YearBuilt'] # Age of the house 
df_new['RenovateAge'] = df_new['YearRemodAdd'] - df_new['YearBuilt']

# %%
# Check if they are >=0
x = df_new[df_new['Age']<0]
x.shape
# Out:
# (0, 31)

# %%
y = df_new[df_new['RenovateAge']<0]
y.shape
# Out:
# (1, 31)

# %%
df_new = df_new.loc[(df_new['RenovateAge']>= 0)] # Age since renovation

# %%
df_new.shape
# Out:
# (2872, 31)

# %%
df_new.head()
# Out:
#    Id  GrLivArea  GarageCars  TotalBsmtSF  FullBath  YearBuilt  YearRemodAdd  \
# 0   1       1710         2.0        856.0         2       2003          2003
# 1   2       1262         2.0       1262.0         2       1976          1976
# 2   3       1786         2.0        920.0         2       2001          2002
# 3   4       1717         3.0        756.0         1       1915          1970
# 4   5       2198         3.0       1145.0         2       2000          2000
#
#    Log_Price  MSSubClass  MSZoning  LotShape  Neighborhood  BldgType  \
# 0  12.247699           5         3         3             5         0
# 1  12.109016           0         3         3            24         0
# 2  12.317171           5         3         0             5         0
# 3  11.849405           6         3         0             6         0
# 4  12.429220           5         3         0            15         0
#
#    HouseStyle  OverallQual  OverallCond  RoofStyle  Exterior2nd  ExterQual  \
# ...

# %%
# Since we already have integrated two meaningul features for house age, the old ones can be removed

df_new_2 = df_new.drop(columns = ['YearBuilt','YearRemodAdd'], axis = 1)

# %%
df_new_2.shape
# Out:
# (2872, 29)

# %%
df_new_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2872 entries, 0 to 2872
# Data columns (total 29 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2872 non-null   int64
#  1   GrLivArea      2872 non-null   int64
#  2   GarageCars     2872 non-null   float64
#  3   TotalBsmtSF    2872 non-null   float64
#  4   FullBath       2872 non-null   int64
#  5   Log_Price      1437 non-null   float64
#  6   MSSubClass     2872 non-null   int32
#  7   MSZoning       2872 non-null   int32
#  8   LotShape       2872 non-null   int32
#  9   Neighborhood   2872 non-null   int32
#  10  BldgType       2872 non-null   int32
#  11  HouseStyle     2872 non-null   int32
#  12  OverallQual    2872 non-null   int32
#  13  OverallCond    2872 non-null   int32
#  14  RoofStyle      2872 non-null   int32
#  15  Exterior2nd    2872 non-null   int32
#  16  ExterQual      2872 non-null   int32
#  17  ExterCond      2872 non-null   int32
# ...

# %%
# Drop unnecessary column: Id

df_new_2 = df_new_2.drop(columns = ['Id'])

# %%
df_new_2.shape
# Out:
# (2872, 28)

# %%
path1 = 'D:\Data Analyst\Task 6.1\Housing price'

# %%
top_num_f1.to_csv(os.path.join(path1,'top_num.csv'))

# %%
df_cat_4.to_csv(os.path.join(path1,'top_cat.csv'))

# %%
df_new_2.to_csv(os.path.join(path1,'df_new.csv'))
